# %% [markdown]
# <a href="https://colab.research.google.com/github/karunrajcseai-hue/karunraj/blob/main/karun%20exp%206.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models

num_samples = 100
timesteps = 10
height, width, channels = 64, 64, 1

x_data = np.random.rand(num_samples, timesteps, height, width, channels)
y_data = np.random.randint(0, 3, size=(num_samples,)) # 3 activity classes

x_data = x_data.reshape(num_samples, timesteps, -1)

# Ex 6
x_train, x_test = x_data[:80], x_data[80:]
y_train, y_test = y_data[:80], y_data[80:]

model = models.Sequential([
    layers.Input(shape=(timesteps, height * width * channels)), # Recommended way to define input shape
    layers.LSTM(64),
    layers.Dense(32, activation='relu'),
    layers.Dense(3, activation='softmax') # 3 activity classes
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=5, batch_size=8, validation_split=0.2)

loss, acc = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {acc * 100:.2f}%")

sample = x_test[0:1]
predicted = model.predict(sample)
print("Predicted Class:", np.argmax(predicted))
# Out:
# Epoch 1/5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.3438 - loss: 1.2360 - val_accuracy: 0.4375 - val_loss: 1.0789
# Epoch 2/5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.3906 - loss: 1.0936 - val_accuracy: 0.4375 - val_loss: 1.0750
# Epoch 3/5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.3906 - loss: 1.0754 - val_accuracy: 0.3125 - val_loss: 1.0975
# Epoch 4/5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.5938 - loss: 1.0363 - val_accuracy: 0.3125 - val_loss: 1.1021
# Epoch 5/5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.4844 - loss: 1.0151 - val_accuracy: 0.4375 - val_loss: 1.0829
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.6500 - loss: 1.0030
# Test Accuracy: 65.00%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# Predicted Class: 1
